# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Dataset

# %%
df=pd.read_csv('/content/car_Dekho_DA.csv')

# %% [markdown]
# # Data Understanding

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# ## Checking for Missing Values

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Car_Name         0.0
# Year             0.0
# Selling_Price    0.0
# Present_Price    0.0
# Kms_Driven       0.0
# Fuel_Type        0.0
# Seller_Type      0.0
# Transmission     0.0
# Owner            0.0
# dtype: float64

# %% [markdown]
# No missing values

# %% [markdown]
# ## Answering the Questions by Analysing the Data

# %%
# 01)From which manufacturing year to which manufacturing year vehicles are present in this data ?
print("In the data the manufacturing year of vehicles ranges from",df['Year'].min(),"to",df['Year'].max(),".")
# Out:
# In the data the manufacturing year of vehicles ranges from 2003 to 2018 .

# %%
# 02)What is the lowest price to which a vehicle is sold ?
print("The lowest price at which a vehicle is sold is:",df['Selling_Price'].min(),"lakhs.")
# Out:
# The lowest price at which a vehicle is sold is: 0.1 lakhs.

# %%
# 03)What is the highest price to which a vehicle is sold ?
print("The highest price at which a vehicle is sold is:",df['Selling_Price'].max(),"lakhs.")
# Out:
# The highest price at which a vehicle is sold is: 35.0 lakhs.

# %%
# 04)How many records are there in this data ?
print("There are",df.shape[0],"records in this data.")
# Out:
# There are 301 records in this data.

# %%
# 05)Are there any missing records in this data ?
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# There are no missing values.

# %%
# 06)How many different vehicles are present in this data ?
print("There are",df['Car_Name'].nunique(),"different vehicles in this data.")
# Out:
# There are 98 different vehicles in this data.

# %%
# 07)Which is the most sold vehicle in this data ?
print("The most sold vehicle in this data is:",df['Car_Name'].value_counts().idxmax())
# Out:
# The most sold vehicle in this data is: city

# %%
# 08)Does the database include any CNG vehicle ? If yes how many of them are there ?
print("The database does include CNG vehicles, and there are",df[df['Fuel_Type']=='CNG'].shape[0],"CNG vehicles.")
# Out:
# The database does include CNG vehicles, and there are 2 CNG vehicles.

# %%
# 09)How many vehicles here are for sell from Individuals directly ?
print("There are",df[df['Seller_Type']=='Individual'].shape[0],"vehicles for sell from Individuals directly.")
# Out:
# There are 106 vehicles for sell from Individuals directly.

# %%
# 10)Does this database contain auto transmission vehicles ? If yes how many of them are there ?
print("Yes, the database does contain auto transmission vehicles, and there are",df[df['Transmission']=='Automatic'].shape[0],"auto transmission vehicles.")
# Out:
# Yes, the database does contain auto transmission vehicles, and there are 40 auto transmission vehicles.

# %%
# 11)How many single person owned vehicles are there in this database ?
print("There are",df[df['Owner']==1].shape[0],"single person owned vehicles in this database.")
# Out:
# There are 10 single person owned vehicles in this database.

# %%
df['Depreciation']=df['Present_Price']-df['Selling_Price']

# %%
# 12)Which is the most and least cost depreciated vehicle in data ?
print("The most cost depreciated vehicle in data is:",df.loc[df['Depreciation']==df['Depreciation'].max(),'Car_Name'].values[0])
print("\nThe least cost depreciated vehicle in data is:",df.loc[df['Depreciation']==df['Depreciation'].min(),'Car_Name'].values[0])
# Out:
# The most cost depreciated vehicle in data is: land cruiser
#
# The least cost depreciated vehicle in data is: Honda Activa 4G

# %%
df.loc[df['Depreciation']==df['Depreciation'].max()]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 86  land cruiser  2010           35.0           92.6       78000    Diesel
#
#    Seller_Type Transmission  Owner  Depreciation
# 86      Dealer       Manual      0          57.6

# %%
df.loc[df['Depreciation']==df['Depreciation'].min()]
# Out:
#             Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 155  Honda Activa 4G  2017           0.48           0.51        4300
#
#     Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 155    Petrol  Individual    Automatic      0          0.03

# %%
# 13)Which brands of vehicles are less affected by cost depreciation ?
brand_depreciation = df.groupby('Car_Name')['Depreciation'].mean().sort_values()
print("These are brands of vehicles are less affected by cost depreciation:")
print(brand_depreciation.head(6).index.tolist())
print("\n")
plt.figure(figsize=(14, 7))
sns.barplot(x=brand_depreciation.index, y=brand_depreciation.values)
plt.xticks(rotation=90)
plt.title('Average Depreciation Rate by Vehicle Brand')
plt.xlabel('Brand')
plt.ylabel('Average Depreciation Rate')
plt.tight_layout()
plt.show()
# Out:
# These are brands of vehicles are less affected by cost depreciation:
# ['TVS Sport ', 'Honda Activa 4G', 'Hero Passion X pro', 'Bajaj Avenger 150', 'Honda Dream Yuga ', 'Yamaha FZ 16']

# %%
# 14)Are there any factors which you feel affect the cost depreciation ?
numerical_columns = ['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'Depreciation']
correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heat Map')
plt.show()

# %% [markdown]
# From this heat map, it is clear that Present_Price and Selling_Price are the most significant factors affecting depreciation, followed by Kms_Driven and Year. The number of previous owners has a lesser impact on depreciation.

# %%
plt.scatter(df.Year,df.Depreciation)
plt.xlabel("Year of Manufacture")
plt.ylabel("Cost Depreciation in lacs")
plt.title("Year of Manufacture vs Cost Depreciation")
plt.show()

# %%
plt.scatter(df.Kms_Driven,df.Depreciation)
plt.xlabel("Kilometers Driven")
plt.ylabel("Cost Depreciation in lacs")
plt.title("Kilometers Driven vs Cost Depreciation")
plt.show()

# %%
# 15)In general selling price is affected by age of vehicle and distance driven by vehicle , is it observable from data ?
plt.scatter(df.Year,df.Selling_Price)
plt.xlabel("Year of Manufacture")
plt.ylabel("Selling Price in lakhs")
plt.title("Year of Manufacture vs Selling Price")
plt.show()
plt.scatter(df.Kms_Driven,df.Selling_Price)
plt.xlabel("Kilometers Driven")
plt.ylabel("Selling Price in lakhs")
plt.title("Kilometers Driven vs Selling Price")
plt.show()

# %% [markdown]
# Yes, we can observe the affect of age of vehicle and distance driven by vehicle on selling price from data.
#
# *   As age of vehicle increases, selling price decreases.
# *   As distance driven by vehicle increases, selling price decreases.

# %%
# 16)Can we get idea about newest vehicles i.e. after 2014 manufactured ?
new_vehicles = df[df['Year'] >= 2015]
new_vehicles.head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation
# 2      Dealer       Manual      0          2.60
# 5      Dealer       Manual      0          0.58
# 6      Dealer       Manual      0          1.37
# 7      Dealer       Manual      0          2.11
# 8      Dealer       Manual      0          0.14

# %%
new_vehicles.reset_index(drop = True, inplace = True)
new_vehicles.head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ciaz  2017           7.25           9.85        6900    Petrol
# 1  vitara brezza  2018           9.25           9.83        2071    Diesel
# 2           ciaz  2015           6.75           8.12       18796    Petrol
# 3        s cross  2015           6.50           8.61       33429    Diesel
# 4           ciaz  2016           8.75           8.89       20273    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation
# 0      Dealer       Manual      0          2.60
# 1      Dealer       Manual      0          0.58
# 2      Dealer       Manual      0          1.37
# 3      Dealer       Manual      0          2.11
# 4      Dealer       Manual      0          0.14

# %%
# 17)Can we find out data of only two wheelers from this data ?
two_wheelers = df[df["Present_Price"] < 3.5]
two_wheelers.head()
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 23                    alto k10  2014           2.50           3.46
# 37                         800  2003           0.35           2.28
# 44                        omni  2012           1.25           2.69
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 23        45280    Petrol      Dealer       Manual      0
# 37       127000    Petrol  Individual       Manual      0
# 44        50000    Petrol      Dealer       Manual      0
# 100        3000    Petrol  Individual       Manual      0
# 101        1400    Petrol  Individual       Manual      0

# %%
two_wheelers.reset_index(drop = True, inplace = True)
two_wheelers.head()
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                   alto k10  2014           2.50           3.46       45280
# 1                        800  2003           0.35           2.28      127000
# 2                       omni  2012           1.25           2.69       50000
# 3  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 4         UM Renegade Mojave  2017           1.70           1.82        1400
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol      Dealer       Manual      0
# 1    Petrol  Individual       Manual      0
# 2    Petrol      Dealer       Manual      0
# 3    Petrol  Individual       Manual      0
# 4    Petrol  Individual       Manual      0

# %%
two_wheelers=two_wheelers.loc[two_wheelers.Car_Name!='alto k10']
two_wheelers=two_wheelers.loc[two_wheelers.Car_Name!='800']
two_wheelers=two_wheelers.loc[two_wheelers.Car_Name!='omni']
two_wheelers.reset_index(drop = True, inplace = True)
two_wheelers.head()
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 1         UM Renegade Mojave  2017           1.70           1.82        1400
# 2                  KTM RC200  2017           1.65           1.78        4000
# 3          Bajaj Dominar 400  2017           1.45           1.60        1200
# 4  Royal Enfield Classic 350  2017           1.35           1.47        4100
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol  Individual       Manual      0
# 1    Petrol  Individual       Manual      0
# 2    Petrol  Individual       Manual      0
# 3    Petrol  Individual       Manual      0
# 4    Petrol  Individual       Manual      0

# %%
# 18)Which is the oldest bike sold here?
two_wheelers.loc[two_wheelers['Year']==two_wheelers['Year'].min()]
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 89  Hero Super Splendor  2005            0.2           0.57       55000
#
#    Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 89    Petrol  Individual       Manual      0          0.37

# %%
# 19)Which is the newest bike sold here?
two_wheelers.loc[two_wheelers['Year']==two_wheelers['Year'].max()]
# Out:
#                      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 1          UM Renegade Mojave  2017           1.70           1.82        1400
# 2                   KTM RC200  2017           1.65           1.78        4000
# 3           Bajaj Dominar 400  2017           1.45           1.60        1200
# 4   Royal Enfield Classic 350  2017           1.35           1.47        4100
# 9   Royal Enfield Classic 350  2017           1.20           1.47       11000
# 26          Bajaj Avenger 220  2017           0.90           0.95        1300
# 28       Honda CB Hornet 160R  2017           0.80           0.87        3000
# 29          Yamaha FZ S V 2.0  2017           0.78           0.84        5000
# 30       Honda CB Hornet 160R  2017           0.75           0.87       11000
# 32          Bajaj Avenger 220  2017           0.75           0.95        3500
# 34         TVS Apache RTR 160  2017           0.65           0.81       11800
# ...

# %%
# 20)Which is the most sold bike here?
fig_dims = (12, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y = two_wheelers.Car_Name,ax=ax, data = two_wheelers)
most_sold=two_wheelers['Car_Name'].value_counts().idxmax()
print(most_sold,"is the most sold bike here.")
# Out:
# Royal Enfield Classic 350 is the most sold bike here.

# %%
# 21)Do you find any deal in two wheelers which exceeded the general expectation ? Can you find reason for it ?
plt.boxplot(two_wheelers.Selling_Price)
plt.show()

# %%
two_wheelers[two_wheelers.Selling_Price > 1.6]
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 1         UM Renegade Mojave  2017           1.70           1.82        1400
# 2                  KTM RC200  2017           1.65           1.78        4000
#
#   Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 0    Petrol  Individual       Manual      0          0.15
# 1    Petrol  Individual       Manual      0          0.12
# 2    Petrol  Individual       Manual      0          0.13

# %% [markdown]
# These are the deals of the two wheelers that are exceeding the general expectation. This maybe due to several factors including demand, condition, customizations, and market dynamics.

# %%
# 22)Can we find out data of only cars from this data ?
cars = df[df["Present_Price"] > 2.0]
cars = cars[~cars.Car_Name.isin(two_wheelers.Car_Name)]
cars.reset_index(drop = True, inplace = True)
cars.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# 23)Which is the oldest car sold here?
cars.loc[cars['Year']==cars['Year'].min()]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 37      800  2003           0.35           2.28      127000    Petrol
# 39      sx4  2003           2.25           7.98       62000    Petrol
#
#    Seller_Type Transmission  Owner
# 37  Individual       Manual      0
# 39      Dealer       Manual      0

# %%
# 24)Which is the newest car sold here?
cars.loc[cars['Year']==cars['Year'].max()]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner
# 5      Dealer       Manual      0

# %%
# 25)Do you find any deal in cars which exceeded the general expectation ? Can you find reason for it ?
plt.boxplot(cars.Selling_Price)
plt.show()

# %%
cars[cars.Selling_Price > 12.5]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 50        fortuner  2012          14.90          30.61      104707    Diesel
# 51        fortuner  2015          23.00          30.61       40000    Diesel
# 52          innova  2017          18.00          19.77       15000    Diesel
# 53        fortuner  2013          16.00          30.61      135000    Diesel
# 59        fortuner  2014          19.99          35.96       41000    Diesel
# 62        fortuner  2014          18.75          35.96       78000    Diesel
# 63        fortuner  2015          23.50          35.96       47000    Diesel
# 64        fortuner  2017          33.00          36.23        6000    Diesel
# 66          innova  2017          19.75          23.15       11000    Petrol
# 69   corolla altis  2016          14.25          20.91       12000    Petrol
# 79        fortuner  2012          14.50          30.61       89000    Diesel
# ...

# %% [markdown]
# ## Additional Analysis

# %%
df.Fuel_Type.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
plt.pie(df.Fuel_Type.value_counts(),labels=["Petrol","Diesel","CNG"],shadow=True)
plt.show()

# %%
df.Seller_Type.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Seller_Type'>

# %%
plt.pie(df.Seller_Type.value_counts(),labels=["Dealer","Individual"],shadow=True)
plt.show()

# %%
plt.scatter(df.Kms_Driven,df.Selling_Price)
plt.xlabel("Kilometers Driven")
plt.ylabel("Selling Price in lakhs")
plt.title("Kilometers Driven vs Selling Price")
plt.show()

# %% [markdown]
# **Insights**
#
# *   Negative correlation
# *   High price for low kms driven
# *   Wide price range at low kms driven (maybe due to other factors)
# *   Outliers

# %% [markdown]
# 7*Analysis Categorical Variables*

# %%
cat_cols = ['Year','Fuel_Type','Seller_Type','Transmission','Owner']

# %%
plt.figure(figsize = [20,10])
i=1
for col in cat_cols:
        plt.subplot(2,3,i)
        sns.barplot(x=df[col],y=df['Depreciation'])
        plt.title(f'{col} vs Depreciation\n', fontdict={'size':25})
        plt.xlabel(col, size=15)
        plt.xticks(size=15, rotation=90)
        i+=1


plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# *   Older cars (from years 2003 to 2009) generally show higher depreciation compared to newer cars (from years 2010 onwards).
# *   Diesel cars tend to have higher depreciation compared to Petrol and CNG cars. And CNG cars have lowest depreciation.
# *   Cars sold by Dealers show higher depreciation compared to those sold by Individuals.
# *   Automatic transmission cars show higher depreciation compared to Manual transmission cars.
# *   The number of owners significantly impacts the depreciation value, with higher ownership leading to higher depreciation.

# %% [markdown]
# *Analysis Numerical Variables*

# %%
num_cols = ['Selling_Price','Kms_Driven','Present_Price','Depreciation']

# %%
sns.pairplot(df[num_cols])
plt.show()

# %% [markdown]
# **Insights**
#
# *   The histogram of the selling price is right-skewed, indicating that most cars have a lower selling price, with fewer cars having a high selling price.
#
# *   There is a weak negative correlation between kilometers driven and selling price, suggesting that cars with higher mileage tend to have lower selling prices.
#
#
# *   There is a strong positive correlation between the present price and the selling price. Higher present prices tend to result in higher selling prices.
#
#
# *   There is a positive correlation between depreciation and selling price, indicating that cars with higher depreciation also tend to have higher selling prices. This might be due to the fact that more expensive cars (higher present price) depreciate more in absolute terms but still have higher selling prices.
#
#
# *   There is a weak negative correlation between kilometers driven and the present price, indicating that cars with higher mileage generally have a lower present price.
#
# *   There is a slight positive correlation between depreciation and kilometers driven, suggesting that cars that have been driven more have higher depreciation.
#
#
# *   There is a strong positive correlation between the present price and depreciation. Cars with higher present prices tend to have higher depreciation.
